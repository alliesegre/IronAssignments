# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np

# %% [markdown]
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# Goal:
#
# song ID | danceability | energy |...|
# ---|---|---|---|
# value|value|value|value|
#
# generate dataframe for one song, one playlist, multiple playlist

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="6fa0b0916c8c4c4990875a5b7d580be4", client_secret= "c293fcd9377e49bfa892119e8d32e031"))

# %% [markdown]
# Get list of categories

# %%
category_id_1= []
for cat in sp.categories()['categories']['items']:
    category_id_1.append(cat['id'])

# %%
category_id_1
# Out:
# ['toplists',
#  'hiphop',
#  'french_variety',
#  'pop',
#  'mood',
#  'edm_dance',
#  'rock',
#  'party',
#  'chill',
#  'radar',
#  'latin',
#  'travel',
#  'in_the_car',
#  'rnb',
#  'workout',
#  'at_home',
#  'sleep',
#  'decades',
#  'jazz',
#  'classical']

# %%
#assigned list
category_id =['wellness',
 'workout',
 'chill',
 'focus',
 'sleep',
 'party',
 'indie_alt',
 'dinner',
 'jazz',
 'mood',
'decades',
'pop',
'toplists',
'rock', 'mood']

# %% [markdown]
# get lists of playlist

# %%
list_of_playlists_1 = []
for item in category_id:
    for j in range(len(sp.category_playlists(item)['playlists']['items'])):
        try:
            list_of_playlists_1.append(sp.category_playlists(item)['playlists']['items'][j]['id'])
        except:
            list_of_playlists_1.append(None)

# %%
list_of_playlists = [x for x in list_of_playlists_1 if x is not None]

# %%
list_of_playlists
# Out:
# ['37i9dQZF1DX9uKNf5jGX6m',
#  '37i9dQZF1DXdejmG21jbny',
#  '37i9dQZF1DWZqd5JICZI0u',
#  '37i9dQZF1DWXe9gFZP0gtP',
#  '37i9dQZF1DXcBbGCLlic3p',
#  '37i9dQZF1DX76Wlfdnj7AP',
#  '37i9dQZF1DX70RN3TfWWJh',
#  '37i9dQZF1DX9uKNf5jGX6m',
#  '37i9dQZF1DXdxcBWuJkbcy',
#  '37i9dQZF1DX9oh43oAzkyx',
#  '37i9dQZF1DXe6bgV3TmZOL',
#  '37i9dQZF1DWXmQEAjlxGhi',
#  '37i9dQZF1DX4eRPd9frC1m',
#  '37i9dQZF1DXadOVCgGhS7j',
#  '37i9dQZF1DX32NsLKyzScr',
#  '37i9dQZF1DWZUTt0fNaCPB',
#  '37i9dQZF1DX0hWmn8d5pRe',
#  '37i9dQZF1DWWPcvnOpPG3x',
#  '37i9dQZF1DWZYWNM3NfvzJ',
#  '37i9dQZF1DX0wiundViT27',
#  '37i9dQZF1DXdc2CX1rMGAc',
#  '37i9dQZF1DXdMm3yYbD7IO',
#  '37i9dQZF1DX0BZrbvIqxCd',
#  '37i9dQZF1DWVhQ5d3I6DeF',
#  '37i9dQZF1DX4WYpdgoIcn6',
#  '37i9dQZF1DWTvNyxOwkztu',
#  '37i9dQZF1DX889U0CL85jj',
#  '37i9dQZF1DX6VdMW310YC7',
#import urllib.request as urllib2
#from urllib2 import HTTPError
#list_of_playlists = []
#for i in range(len(category_id)):
   # try:
    #    list_of_playlists.append(sp.category_playlists(str(i))['playlists']['items']['id'])
 #   except HTTPError as err:
         #  if err.code == 404:
    #            print(sp.category_playlists(str(i))['playlists']['items']['id'], 'missing') 
         #  else:
          #     raise

# %% [markdown]
# Get tracks info from playlists

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks('spotify', playlist_id)
    tracks = results['items']
    while results['next']:
        # print(results['next'])
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#def get_tracks_info(playlist_id):
songs_names = []
songs_ids = []
artist_name = []
def track_info(playlist_id):
    #features= []
    playlist_track = get_playlist_tracks("spotify", playlist_id)

    for i in range(len(sp.playlist_items(playlist_id)["items"])):
            artists=[]
            try:
                for a in range(len(playlist_track[i]['track']['artists'])):
                        artists.append(playlist_track[i]['track']['artists'][a]['name'])
            except TypeError:
                artists.append(None)
            artist_name.append(artists)
            try:
                songs_ids.append(playlist_track[i]['track']['id'])
            except TypeError:
                songs_ids.append(None)
            try:
                songs_names.append(playlist_track[i]['track']['name'])
            except TypeError:
                songs_names.append(None)

# %%
features= []
def get_features(item):
        try:
            features.append(sp.audio_features(item))
        except TypeError:
            features.append([{'danceability':None,
   'energy': None,
   'key': None,
   'loudness': None,
   'mode': None,
   'speechiness': None,
   'acousticness': None,
   'instrumentalness': None,
   'liveness': None,
   'valence': None,
   'tempo': None,
   'type': 'empty',
   'id': 'empty',
   'uri': 'empty',
   'track_href': 'empty',
   'analysis_url': 'empty',
   'duration_ms': None,
   'time_signature': None}])
             
        #feat_df = pd.DataFrame(features).stack().apply(pd.Series)

# %%
for i in list_of_playlists:
    track_info(i)

# %%
df = pd.DataFrame({"songs_names": songs_names, "songs_ids": songs_ids, "artists_names": artist_name})

# %%
df
# Out:
#          songs_names               songs_ids           artists_names
# 0      Astral Wonder  7En6m2Yg3J1zAq895bxl78           [Moon Oceans]
# 1          Evergreen  633YySlXq6qxSdCLFovXdv           [Cooper Sams]
# 2        Karlavagnen  7kdnp9XpskkNjGDRlmb8nw           [Karlavagnen]
# 3            Montana  0gBjWQIJ9KcdzT26UzkNqn         [Isobel Belano]
# 4           Electron  0KkNeFOoAKW0NkhaleFeGk              [Sisi Row]
# ...              ...                     ...                     ...
# 11887         No Way  2UhhSTIAKDa5lwWItkYvIE  [The Naked And Famous]
# 11888       Komorebi  2ztHL4aV76oeCe6DDWpky3          [Craft Spells]
# 11889        On Call  2rmRhDnnIA0FuXKyDTzhGZ         [Kings of Leon]
# 11890       Westside  5BtyHl1eRqip2PkHhFYzHG             [The Kooks]
# 11891        You & I  6SgHlKcfkRQ6XohmDR1ugQ         [Local Natives]
#
# [11892 rows x 3 columns]

# %%
for item in songs_ids:
    get_features(item)

# %%
feat_df = pd.DataFrame(features).stack().apply(pd.Series)

# %%
feat_df
# Out:
#          danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0     0        0.1710  0.1430    0   -24.178     1       0.0431       0.95200
# 1     0        0.1310  0.0860    6   -20.439     1       0.0332       0.99300
# 2     0        0.0916  0.0343   11   -26.745     1       0.0419       0.84000
# 3     0        0.3380  0.0901    3   -22.303     1       0.0323       0.76200
# 4     0        0.2500  0.2010    0   -21.141     1       0.0377       0.89500
# ...               ...     ...  ...       ...   ...          ...           ...
# 11887 0        0.4480  0.8500    7    -6.564     1       0.0416       0.00135
# 11888 0        0.1800  0.5550    1    -8.784     0       0.0326       0.21600
# 11889 0        0.3070  0.7910    7    -5.408     1       0.1190       0.02850
# 11890 0        0.7670  0.6630    9    -4.988     0       0.0333       0.25200
# 11891 0        0.4420  0.8660    2    -7.916     0       0.0567       0.54500
#
#          instrumentalness  liveness  valence    tempo            type  \
# 0     0          0.924000    0.1110   0.0374   72.116  audio_features
# 1     0          0.877000    0.0794   0.0397   54.749  audio_features
# 2     0          0.762000    0.1700   0.0424   82.815  audio_features
# 3     0          0.699000    0.0891   0.1150  135.633  audio_features
# 4     0          0.969000    0.2270   0.0663   59.005  audio_features
# ...                   ...       ...      ...      ...             ...
# 11887 0          0.276000    0.2320   0.0825  129.946  audio_features
# 11888 0          0.417000    0.1020   0.5630  166.476  audio_features
# 11889 0          0.000804    0.3950   0.1410  193.356  audio_features
# 11890 0          0.000024    0.1060   0.8210  112.017  audio_features
# 11891 0          0.595000    0.0976   0.3200   94.970  audio_features
#
#                              id                                   uri  \
# 0     0  7En6m2Yg3J1zAq895bxl78  spotify:track:7En6m2Yg3J1zAq895bxl78
# 1     0  633YySlXq6qxSdCLFovXdv  spotify:track:633YySlXq6qxSdCLFovXdv
# 2     0  7kdnp9XpskkNjGDRlmb8nw  spotify:track:7kdnp9XpskkNjGDRlmb8nw
# 3     0  0gBjWQIJ9KcdzT26UzkNqn  spotify:track:0gBjWQIJ9KcdzT26UzkNqn
# 4     0  0KkNeFOoAKW0NkhaleFeGk  spotify:track:0KkNeFOoAKW0NkhaleFeGk
# ...                         ...                                   ...
# 11887 0  2UhhSTIAKDa5lwWItkYvIE  spotify:track:2UhhSTIAKDa5lwWItkYvIE
# 11888 0  2ztHL4aV76oeCe6DDWpky3  spotify:track:2ztHL4aV76oeCe6DDWpky3
# 11889 0  2rmRhDnnIA0FuXKyDTzhGZ  spotify:track:2rmRhDnnIA0FuXKyDTzhGZ
# 11890 0  5BtyHl1eRqip2PkHhFYzHG  spotify:track:5BtyHl1eRqip2PkHhFYzHG
# 11891 0  6SgHlKcfkRQ6XohmDR1ugQ  spotify:track:6SgHlKcfkRQ6XohmDR1ugQ
#
#                                                 track_href  \
# 0     0  https://api.spotify.com/v1/tracks/7En6m2Yg3J1z...
# 1     0  https://api.spotify.com/v1/tracks/633YySlXq6qx...
# 2     0  https://api.spotify.com/v1/tracks/7kdnp9XpskkN...
# 3     0  https://api.spotify.com/v1/tracks/0gBjWQIJ9Kcd...
# 4     0  https://api.spotify.com/v1/tracks/0KkNeFOoAKW0...
# ...                                                    ...
# 11887 0  https://api.spotify.com/v1/tracks/2UhhSTIAKDa5...
# 11888 0  https://api.spotify.com/v1/tracks/2ztHL4aV76oe...
# 11889 0  https://api.spotify.com/v1/tracks/2rmRhDnnIA0F...
# 11890 0  https://api.spotify.com/v1/tracks/5BtyHl1eRqip...
# 11891 0  https://api.spotify.com/v1/tracks/6SgHlKcfkRQ6...
#
#                                               analysis_url  duration_ms  \
# 0     0  https://api.spotify.com/v1/audio-analysis/7En6...       181091
# 1     0  https://api.spotify.com/v1/audio-analysis/633Y...       225882
# 2     0  https://api.spotify.com/v1/audio-analysis/7kdn...       203455
# 3     0  https://api.spotify.com/v1/audio-analysis/0gBj...       166325
# 4     0  https://api.spotify.com/v1/audio-analysis/0KkN...       214800
# ...                                                    ...          ...
# 11887 0  https://api.spotify.com/v1/audio-analysis/2Uhh...       329800
# 11888 0  https://api.spotify.com/v1/audio-analysis/2ztH...       263691
# 11889 0  https://api.spotify.com/v1/audio-analysis/2rmR...       201800
# 11890 0  https://api.spotify.com/v1/audio-analysis/5Bty...       210193
# 11891 0  https://api.spotify.com/v1/audio-analysis/6SgH...       261760
#
#          time_signature
# 0     0               5
# 1     0               5
# 2     0               5
# 3     0               4
# 4     0               4
# ...                 ...
# 11887 0               4
# 11888 0               3
# 11889 0               4
# 11890 0               4
# 11891 0               4
#
# [11891 rows x 18 columns]

# %%
feat_df.to_csv('features.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-b6c522278a15> in <module>
# ----> 1 feat_df.to_csv('features.csv')
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3382         )
#    3383
# -> 3384         return DataFrameRenderer(formatter).to_csv(
#    3385             path_or_buf,
#    3386             line_terminator=line_terminator,
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\OneDrive\Documents\anaconda new\envs\ironhack\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: 'features.csv'

# %%
feat_df.reset_index()
# Out:
#        level_0  level_1  danceability  energy  key  loudness  mode  \
# 0            0        0        0.1710  0.1430    0   -24.178     1
# 1            1        0        0.1310  0.0860    6   -20.439     1
# 2            2        0        0.0916  0.0343   11   -26.745     1
# 3            3        0        0.3380  0.0901    3   -22.303     1
# 4            4        0        0.2500  0.2010    0   -21.141     1
# ...        ...      ...           ...     ...  ...       ...   ...
# 11886    11887        0        0.4480  0.8500    7    -6.564     1
# 11887    11888        0        0.1800  0.5550    1    -8.784     0
# 11888    11889        0        0.3070  0.7910    7    -5.408     1
# 11889    11890        0        0.7670  0.6630    9    -4.988     0
# 11890    11891        0        0.4420  0.8660    2    -7.916     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0431       0.95200          0.924000    0.1110   0.0374
# 1           0.0332       0.99300          0.877000    0.0794   0.0397
# 2           0.0419       0.84000          0.762000    0.1700   0.0424
# 3           0.0323       0.76200          0.699000    0.0891   0.1150
# 4           0.0377       0.89500          0.969000    0.2270   0.0663
# ...            ...           ...               ...       ...      ...
# 11886       0.0416       0.00135          0.276000    0.2320   0.0825
# 11887       0.0326       0.21600          0.417000    0.1020   0.5630
# 11888       0.1190       0.02850          0.000804    0.3950   0.1410
# 11889       0.0333       0.25200          0.000024    0.1060   0.8210
# 11890       0.0567       0.54500          0.595000    0.0976   0.3200
#
#          tempo            type                      id  \
# 0       72.116  audio_features  7En6m2Yg3J1zAq895bxl78
# 1       54.749  audio_features  633YySlXq6qxSdCLFovXdv
# 2       82.815  audio_features  7kdnp9XpskkNjGDRlmb8nw
# 3      135.633  audio_features  0gBjWQIJ9KcdzT26UzkNqn
# 4       59.005  audio_features  0KkNeFOoAKW0NkhaleFeGk
# ...        ...             ...                     ...
# 11886  129.946  audio_features  2UhhSTIAKDa5lwWItkYvIE
# 11887  166.476  audio_features  2ztHL4aV76oeCe6DDWpky3
# 11888  193.356  audio_features  2rmRhDnnIA0FuXKyDTzhGZ
# 11889  112.017  audio_features  5BtyHl1eRqip2PkHhFYzHG
# 11890   94.970  audio_features  6SgHlKcfkRQ6XohmDR1ugQ
#
#                                         uri  \
# 0      spotify:track:7En6m2Yg3J1zAq895bxl78
# 1      spotify:track:633YySlXq6qxSdCLFovXdv
# 2      spotify:track:7kdnp9XpskkNjGDRlmb8nw
# 3      spotify:track:0gBjWQIJ9KcdzT26UzkNqn
# 4      spotify:track:0KkNeFOoAKW0NkhaleFeGk
# ...                                     ...
# 11886  spotify:track:2UhhSTIAKDa5lwWItkYvIE
# 11887  spotify:track:2ztHL4aV76oeCe6DDWpky3
# 11888  spotify:track:2rmRhDnnIA0FuXKyDTzhGZ
# 11889  spotify:track:5BtyHl1eRqip2PkHhFYzHG
# 11890  spotify:track:6SgHlKcfkRQ6XohmDR1ugQ
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7En6m2Yg3J1z...
# 1      https://api.spotify.com/v1/tracks/633YySlXq6qx...
# 2      https://api.spotify.com/v1/tracks/7kdnp9XpskkN...
# 3      https://api.spotify.com/v1/tracks/0gBjWQIJ9Kcd...
# 4      https://api.spotify.com/v1/tracks/0KkNeFOoAKW0...
# ...                                                  ...
# 11886  https://api.spotify.com/v1/tracks/2UhhSTIAKDa5...
# 11887  https://api.spotify.com/v1/tracks/2ztHL4aV76oe...
# 11888  https://api.spotify.com/v1/tracks/2rmRhDnnIA0F...
# 11889  https://api.spotify.com/v1/tracks/5BtyHl1eRqip...
# 11890  https://api.spotify.com/v1/tracks/6SgHlKcfkRQ6...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7En6...       181091
# 1      https://api.spotify.com/v1/audio-analysis/633Y...       225882
# 2      https://api.spotify.com/v1/audio-analysis/7kdn...       203455
# 3      https://api.spotify.com/v1/audio-analysis/0gBj...       166325
# 4      https://api.spotify.com/v1/audio-analysis/0KkN...       214800
# ...                                                  ...          ...
# 11886  https://api.spotify.com/v1/audio-analysis/2Uhh...       329800
# 11887  https://api.spotify.com/v1/audio-analysis/2ztH...       263691
# 11888  https://api.spotify.com/v1/audio-analysis/2rmR...       201800
# 11889  https://api.spotify.com/v1/audio-analysis/5Bty...       210193
# 11890  https://api.spotify.com/v1/audio-analysis/6SgH...       261760
#
#        time_signature
# 0                   5
# 1                   5
# 2                   5
# 3                   4
# 4                   4
# ...               ...
# 11886               4
# 11887               3
# 11888               4
# 11889               4
# 11890               4
#
# [11891 rows x 20 columns]

# %%
final_df = pd.DataFrame(np.hstack([df, feat_df]), columns=df.columns.append(feat_df.columns))

# %%
final_df
final_df['artists_names'] = [','.join(map(str, l)) for l in final_df['artists_names']]

# %%
final_df.drop(['type', 'id', 'uri','track_href','analysis_url','duration_ms','time_signature'], axis=1)

# %% [markdown]
# Clustering

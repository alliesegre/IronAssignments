# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
#from urllib.parse import urlparse
#from urlparse import urljoin

url = "https://www.billboard.com/charts/hot-100"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
print(soup.prettify())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len_mov = len(soup.select("span.chart-element__information"))
artist =[]
song = []

for i in range(len_mov):
     artist.append(soup.select("span.chart-element__information__artist")[i].get_text())
     song.append(soup.select("span.chart-element__information__song")[i].get_text())

# %%
ready_to_clean_1= pd.DataFrame({'artist':artist,'song':song})

# %%
ready_to_clean_1
# Out:
#                             artist                   song
# 0                   Olivia Rodrigo        Drivers License
# 1                    Ariana Grande                  34+35
# 2         Lil Tjay Featuring 6LACK       Calling My Phone
# 3                       The Weeknd        Blinding Lights
# 4                          Cardi B                     Up
# ..                             ...                    ...
# 95                    Jordan Davis          Almost Maybes
# 96   Saweetie Featuring Jhene Aiko    Back To The Streets
# 97         Juice WRLD & Young Thug                Bad Boy
# 98  YBN Nahmir Featuring 21 Savage             Opp Stoppa
# 99                   Rascal Flatts  How They Remember You
#
# [100 rows x 2 columns]

# %% [markdown]
# Charts Italy

# %%
from bs4 import BeautifulSoup

import requests

import pandas as pd
from splinter import Browser
from selenium import webdriver

# %%
url = "https://top40-charts.com/chart.php?cid=18&date="

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#">
#  <head>
#   <!-- logpage chart 42 de -->
#   <!-- Hotjar Tracking Code for top40-charts.com -->
#   <script>
#    (function(h,o,t,j,a,r){
# 	        h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
# 	        h._hjSettings={hjid:1094028,hjsv:6};
# 	        a=o.getElementsByTagName('head')[0];
# 	        r=o.createElement('script');r.async=1;
# 	        r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
# 	        a.appendChild(r);
# 	    })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Italy Top 20 @  Top40-Charts.com - New Songs &amp; Videos from 49 Top 20 &amp; Top 40 Music Charts from 30 Countries
#   </title>
#   <meta content="66d0d8a34c07b69d53dc27a7" name="purpleads-verification"/>
# ...

# %%
soup.select("tr > td:nth-child(3) > a")[0].get_text()
# Out:
# 'Mace, Blanco & Salmo'

# %%
len_mov = len(soup.select("table > tbody > tr > td:nth-child(1) > table > tbody"))
artist =[]
song = []

for i in range(0,20):
    artist.append(soup.select("tr > td:nth-child(3) > a")[i].get_text())
    song.append(soup.select("div > b > a")[i].get_text())

# %%
#body > div:nth-child(4) > div > div.ContentContainer > table > tbody > tr > td:nth-child(1) > table > tbody

# %%
ready_to_clean_2 = pd.DataFrame({'artist':artist,'song':song})

# %%
ready_to_clean_2
# Out:
#                                                artist                   song
# 0                                Mace, Blanco & Salmo      La Canzone Nostra
# 1                                            Gazzelle                 Destri
# 2       Takagi & Ketra, Marco Mengoni & Frah Quintale         Venere E Marte
# 3                              Gazzelle & Tha Supreme             Coltellata
# 4              Sfera Ebbasta, Marracash & Gue Pequeno                Tik Tok
# 5                                              Weeknd        Save Your Tears
# 6                   Ernia & Pinguini Tattici Nucleari       Ferma A Guardare
# 7                           Pinguini Tattici Nucleari             Scooby Doo
# 8                                         Sangiovanni                   Lady
# 9                            Sfera Ebbasta & J Balvin                   Baby
# 10                                              Ernia          Superclassico
# ...

# %%
ready_to_clean_2.to_csv('top_italy.csv')
